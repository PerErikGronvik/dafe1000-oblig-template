# %% [markdown]
# # Oblig — DAFE xxxx
#
# **Studentnummer:** _Ditt studentnummer her_
#
#
# ---

# %% [markdown]
# ## Importerer biblioteker

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Oppgave 1
#
# _Beskriv oppgaven her._
